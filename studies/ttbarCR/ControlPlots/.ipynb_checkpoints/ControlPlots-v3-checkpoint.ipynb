# %%
from ControlPlots import *

# %%
# %load_ext jupyter_extension

# %%
# Knobs
flatten_babies = False
use_norm_weight = True
use_jet_weights = False
use_trailing_P_weight = False
baby_ver = 'v6-1-0'
year_ = 2018

# %%
if use_norm_weight and use_jet_weights:
    plot_output_dir = f'/home/users/aaarora/public_html/controlPlots/{str(year_)}/plots_w_both/'
elif use_norm_weight and not use_jet_weights:
    plot_output_dir = f'/home/users/aaarora/public_html/controlPlots/{str(year_)}/plots_w_only_norm/'
elif not use_norm_weight and use_jet_weights:
    plot_output_dir = f'/home/users/aaarora/public_html/controlPlots/{str(year_)}/plots_w_only_jet/'
else:
    plot_output_dir = f'/home/users/aaarora/public_html/controlPlots/{str(year_)}/plots_w_neither/'

# %%
df_dict = make_df_dict(year_, baby_ver, 'TTJets', 'ST', 'TTV', 'VV')
# Out:
# Appending..: 100%|██████████| 9/9 [00:13<00:00,  1.50s/it]
# Appending..: 100%|██████████| 17/17 [00:01<00:00,  8.78it/s]
# Appending..: 100%|██████████| 12/12 [00:04<00:00,  2.49it/s]
# Appending..: 100%|██████████| 31/31 [00:03<00:00, 10.09it/s]

# %%
data = ControlPlot('MuonEG', baby_ver).df
data_c = data[data['year']==year_]
# Out:
# Appending..: 100%|██████████| 17/17 [00:03<00:00,  5.20it/s]

# %%
weights_dict, integral_w = build_weights_dict(df_dict, data_c, use_norm_weight, use_jet_weights, use_trailing_P_weight)

# %% [markdown]
# x----------------------------------------------PLOTS BEGIN HERE----------------------------------------------x

# %%
# %%skip not $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "jet_eta", bins=np.linspace(-3,3,10), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Jet $\eta$")
# plt.savefig(plot_output_dir + 'jet_eta.png')

# %%
# %%skip not $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "jet_phi", bins=np.linspace(-np.pi,np.pi,10), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Jet $\phi$")
# plt.savefig(plot_output_dir + 'jet_phi.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "met", bins=np.linspace(0,500,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel="MET")
# plt.savefig(plot_output_dir + 'met.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "vbs_dijet_mass", bins=np.linspace(0,2000,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel="$M_{jj}$")
# plt.savefig(plot_output_dir + 'vbs_dijet_mass.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "dilep_mass", bins=np.linspace(0,500,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel="$M_{\ell\ell}$")
# plt.savefig(plot_output_dir + 'dilep_mass.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "num_jets", bins=np.linspace(0,12,13), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel="Number of Jets")
# plt.savefig(plot_output_dir + 'num_jets.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "leading_vbs_jet_P", bins=np.linspace(0,2500,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Leading VBS Jet P")
# plt.savefig(plot_output_dir + 'leading_vbs_jet_P.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "trailing_vbs_jet_P", bins=np.linspace(0,2000,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Trailing VBS Jet P")
# plt.savefig(plot_output_dir + 'trailing_vbs_jet_P.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "leading_vbs_jet_pt", bins=np.linspace(0,1000,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Leading VBS Jet $p_T$")
# plt.savefig(plot_output_dir + 'leading_vbs_jet_pt.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "trailing_vbs_jet_pt", bins=np.linspace(0,250,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Trailing VBS Jet $p_T$")
# plt.savefig(plot_output_dir + 'trailing_vbs_jet_pt.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "leading_vbs_jet_eta", bins=np.linspace(-5,5,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Leading VBS Jet $\eta$")
# plt.savefig(plot_output_dir + 'leading_vbs_jet_eta.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "trailing_vbs_jet_eta", bins=np.linspace(-5,5,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Trailing VBS Jet $\eta$")
# plt.savefig(plot_output_dir + 'trailing_vbs_jet_eta.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "leading_vbs_jet_phi", bins=np.linspace(-np.pi,np.pi,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Leading VBS Jet $\phi$")
# plt.savefig(plot_output_dir + 'leading_vbs_jet_phi.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "trailing_vbs_jet_phi", bins=np.linspace(-np.pi,np.pi,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Trailing VBS Jet $\phi$")
# plt.savefig(plot_output_dir + 'trailing_vbs_jet_phi.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "leading_lep_pt", bins=np.linspace(0,300,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Leading Lepton $p_T$")
# plt.savefig(plot_output_dir + 'leading_lep_pt.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "trailing_lep_pt", bins=np.linspace(0,300,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Trailing Lepton $p_T$")
# plt.savefig(plot_output_dir + 'trailing_lep_pt.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "leading_lep_eta", bins=np.linspace(-2.5,2.5,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Leading Lepton $\eta$")
# plt.savefig(plot_output_dir + 'leading_lep_eta.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "trailing_lep_eta", bins=np.linspace(-2.5,2.5,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Trailing Lepton $\eta$")
# plt.savefig(plot_output_dir + 'trailing_lep_eta.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "leading_lep_phi", bins=np.linspace(-np.pi,np.pi,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Leading Lepton $\phi$")
# plt.savefig(plot_output_dir + 'leading_lep_phi.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# typical_hist(df_dict, weights_dict, data_c, "trailing_lep_phi", bins=np.linspace(-np.pi,np.pi,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"Trailing Lepton $\phi$")
# plt.savefig(plot_output_dir + 'trailing_lep_phi.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# not_a_typical_hist(df_dict, weights_dict, data_c, "leading_vbs_jet_eta", "trailing_vbs_jet_eta", bins=np.linspace(0,2.5*np.pi,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"VBS Jets $|d\eta$|")
# plt.savefig(plot_output_dir + 'vbs_jet_deta.png')

# %%
# %%skip $flatten_babies
# # Stacked hist
# fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
# not_a_typical_hist(df_dict, weights_dict, data_c, "leading_vbs_jet_phi", "trailing_vbs_jet_phi", bins=np.linspace(0,2*np.pi,21), hist_axes=ax1, ratio_axes=ax2)
#
# # Dummy plot to add text to legend
# ax1.plot(
#     [],[],' ',
#     label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % integral_w
# )
# format_hist_axes(df_dict, ax1)
# format_ratio_axes(ax2, xlabel=r"VBS Jets $|d\phi$|")
# plt.savefig(plot_output_dir + 'vbs_jet_dphi.png')
