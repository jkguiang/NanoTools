# %%
from ControlPlots import *

# %%
# Knobs
baby_ver = 'v6-1-0'
year_ = 2016

# %%
CP = ControlPlot(['TTJets', 'ST', 'TTV', 'VV', 'MuonEG'], data_name='MuonEG', year=year_, baby_ver=baby_ver)
# Out:
# ...
# Appending..: 100%|██████████| 17/17 [00:03<00:00,  4.92it/s]

# %% [markdown]
# x----------------------------------------------PLOTS BEGIN HERE----------------------------------------------x

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("met", bins=np.linspace(0,300,31), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"MET")

#plt.savefig(plot_output_dir + 'dilep_mass.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("vbs_dijet_mass", bins=np.linspace(0,2000,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"$M_{jj}$")

#plt.savefig(plot_output_dir + 'vbs_dijet_mass.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("dilep_mass", bins=np.linspace(0,500,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"$M_{\ell\ell}$")

#plt.savefig(plot_output_dir + 'dilep_mass.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("num_jets", bins=np.linspace(0,12,13), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Number of Jets")

#plt.savefig(plot_output_dir + 'num_jets.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("leading_vbs_jet_P", bins=np.linspace(0,2500,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Leading VBS Jet P")

#plt.savefig(plot_output_dir + 'leading_vbs_jet_P.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("trailing_vbs_jet_P", bins=np.linspace(0,2000,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Trailing VBS Jet P")

#plt.savefig(plot_output_dir + 'trailing_vbs_jet_P.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("leading_vbs_jet_pt", bins=np.linspace(0,600,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Leading VBS Jet $p_T$")

#plt.savefig(plot_output_dir + 'trailing_vbs_jet_P.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("trailing_vbs_jet_pt", bins=np.linspace(0,250,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Trailing VBS Jet $p_T$")

#plt.savefig(plot_output_dir + 'trailing_vbs_jet_pt.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("leading_vbs_jet_eta", bins=np.linspace(-5,5,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Leading VBS Jet $\eta$")

#plt.savefig(plot_output_dir + 'trailing_vbs_jet_pt.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("trailing_vbs_jet_eta", bins=np.linspace(-5,5,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Trailing VBS Jet $\eta$")

#plt.savefig(plot_output_dir + 'trailing_vbs_jet_eta.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("leading_vbs_jet_phi", bins=np.linspace(-np.pi,np.pi,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Leading VBS Jet $\phi$")

#plt.savefig(plot_output_dir + 'leading_vbs_jet_phi.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("trailing_vbs_jet_phi", bins=np.linspace(-np.pi,np.pi,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Trailing VBS Jet $\phi$")

#plt.savefig(plot_output_dir + 'trailing_vbs_jet_phi.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("leading_lep_pt", bins=np.linspace(0,300,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Leading Lepton $p_T$")

#plt.savefig(plot_output_dir + 'leading_lep_pt.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("trailing_lep_pt", bins=np.linspace(0,150,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Trailing Lepton $p_T$")

#plt.savefig(plot_output_dir + 'trailing_lep_pt.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("leading_lep_eta", bins=np.linspace(-2.5,2.5,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Leading Lepton $\eta$")

#plt.savefig(plot_output_dir + 'leading_lep_eta.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("trailing_lep_eta", bins=np.linspace(-2.5,2.5,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Trailing Lepton $\eta$")

#plt.savefig(plot_output_dir + 'trailing_lep_eta.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("leading_lep_phi", bins=np.linspace(-np.pi,np.pi,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Leading Lepton $\phi$")

#plt.savefig(plot_output_dir + 'leading_lep_phi.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.comparison_plot("trailing_lep_phi", bins=np.linspace(-np.pi,np.pi,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)

CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"Trailing Lepton $\phi$")

#plt.savefig(plot_output_dir + 'trailing_lep_phi.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.difference_plot("leading_vbs_jet_eta", "trailing_vbs_jet_eta", bins=np.linspace(0,2.5*np.pi,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)
CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"VBS Jets $|d\eta$|")
#plt.savefig(plot_output_dir + 'vbs_jet_deta.png')

# %%
# Stacked hist
fig, (ax1, ax2) = plt.subplots(2,sharex=True,figsize=(10,10),gridspec_kw=dict(height_ratios=[5, 2]))
CP.difference_plot("leading_vbs_jet_phi", "trailing_vbs_jet_phi", bins=np.linspace(0,np.pi,21), hist_axes=ax1, ratio_axes=ax2)

# Dummy plot to add text to legend
ax1.plot(
    [],[],' ',
    label=r"$\bf{MC\hspace{0.25} scaled\hspace{0.25} by\hspace{0.25} %0.2f}$" % CP.normalization_weight
)
CP.format_hist_axes(ax1)
CP.format_ratio_axes(ax2, xlabel=r"VBS Jets $|d\phi$|")
#plt.savefig(plot_output_dir + 'vbs_jet_dphi.png')
