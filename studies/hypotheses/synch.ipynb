# %%
import uproot
import glob
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.ticker import AutoMinorLocator

plt.rc('font', size=18)

# %%
cms4_df = ((uproot.open("output/ttbar_cms4_0.root")).get("tree")).pandas.df()

nano_df = []
for nano_baby in glob.glob("output/ttbar_nano_*"):
    nano_df.append(((uproot.open(nano_baby)).get("tree")).pandas.df())
nano_df = pd.concat(nano_df)

# %%
cms4_df.shape
# Out:
# (243424, 19)

# %%
nano_df.shape
# Out:
# (235739, 15)

# %%
cms4_events_in_nano = np.isin(cms4_df.event, nano_df.event)
nano_events_in_cms4 = np.isin(nano_df.event, cms4_df.event)

# %%
np.sum(cms4_events_in_nano)
# Out:
# 235739

# %%
np.sum(nano_events_in_cms4)
# Out:
# 235739

# %%
cms4_df.columns
# Out:
# Index([u'leader_eta', u'lagger_isTriggerSafe', u'leader_isTriggerSafe',
#        u'lagger_id', u'leader_id', u'lagger_idx', u'leader_idx',
#        u'leader_is_loose', u'lagger_is_loose', u'leader_is_tight',
#        u'lagger_is_tight', u'lagger_eta', u'hyp_class', u'leader_pt',
#        u'lagger_pt', u'is_dilepton_event', u'event', u'run', u'lumi'],
#       dtype='object')

# %%
np.sum(cms4_df.is_dilepton_event)
# Out:
# 20033

# %%
np.sum(nano_df.is_dilepton_event)
# Out:
# 5732

# %%
cms4_synch_df = cms4_df[cms4_df.is_dilepton_event]
nano_synch_df = nano_df[np.isin(nano_df.event, cms4_synch_df.event)]

# %%
def scatter_hist_1D(df, label="", fmt="bs", log=False, 
                    fig=None, axes=None):
    if not fig or not axes:
        fig = plt.figure(figsize=(6.4,6.4))
        axes = plt.subplot(111)
    bin_edges = np.arange(1,9)
    # Get histogram values
    counts, _ = np.histogram(df.hyp_class, bins=bin_edges)
    # Get bin dimensions
    bin_widths = bin_edges[1:]-bin_edges[:-1]
    bin_centers = bin_edges[:-1]+0.5*bin_widths
    # Plot error bars
    axes.errorbar(bin_edges[:-1], counts, xerr=0.5*bin_widths,
                  fmt=fmt, label=label);
    axes.margins(x=0) # Remove axis margins
    axes.yaxis.set_minor_locator(AutoMinorLocator())
    # Plot formatting
    plt.xticks(np.arange(1,8));
    if log:
        plt.yscale('log')
    return

def hyp_synch_plot(cms4_synch_df, nano_synch_df,
                   cms4_label="CMS4", nano_label="Nano"):
    fig = plt.figure(figsize=(6.4*2.25,6.4))

    axes1 = plt.subplot(121)
    scatter_hist_1D(cms4_synch_df, label=cms4_label, fmt="bs", 
                    log=False, fig=fig, axes=axes1)
    scatter_hist_1D(nano_synch_df, label=nano_label, fmt="ro", 
                    log=False, fig=fig, axes=axes1)

    plt.legend();
    plt.title("Hyp Comparison (linscale)");
    plt.xticks([1,2,3,4,5,6,7], 
               ["LL", "LT | TL", "TT", "OS TT", "", r"Z | $\gamma*$", ""],
               rotation="45", ha="right");
    plt.ylabel("Events");
    plt.grid(which="both");

    axes2 = plt.subplot(122)
    scatter_hist_1D(cms4_synch_df, label=cms4_label, fmt="bs", 
                    log=True, fig=fig, axes=axes2)
    scatter_hist_1D(nano_synch_df, label=nano_label, fmt="ro", 
                    log=True, fig=fig, axes=axes2)

    plt.legend();
    plt.title("Hyp Comparison (logscale)");
    plt.xticks([1,2,3,4,5,6,7], 
               ["LL", "LT | TL", "TT", "OS TT", "", r"Z | $\gamma*$", ""],
               rotation="45", ha="right")
    plt.ylabel("Events");
    plt.grid(which="both");
    
def hyp_pt_plot(cms4_df, nano_df, hyp=1,
                   cms4_label="CMS4", nano_label="Nano"):
    # Get synch events
    hyp_synch_events = (np.isin(nano_df.event,
                                cms4_df[cms4_df.hyp_class == hyp].event))
    # Get synch dfs
    cms4_synch_df = cms4_df[cms4_df.hyp_class == hyp]
    nano_synch_df = nano_df[hyp_synch_events]
    
    # Set up figure
    fig = plt.figure(figsize=(6.4*2.25,4.8))

    # Left plot (leaders)
    axes1 = plt.subplot(121)
    plt.hist(cms4_synch_df.leader_pt, bins=np.linspace(0,250,26),
             color="b", alpha=0.5, label=cms4_label);
    plt.hist(nano_synch_df[nano_synch_df.is_dilepton_event].leader_pt, bins=np.linspace(0,250,26),
             color="r", alpha=0.5, label=nano_label);
    # Formatting
    axes1.xaxis.set_minor_locator(AutoMinorLocator())
    plt.xlabel(r"$p_{T}^{leading}$");
    plt.ylabel("Events");
    plt.legend();

    # Right plot (laggers)
    axes2 = plt.subplot(122)
    plt.hist(cms4_synch_df.lagger_pt, bins=np.linspace(0,250,26),
             color="b", alpha=0.5, label=cms4_label);
    plt.hist(nano_synch_df[nano_synch_df.is_dilepton_event].lagger_pt, bins=np.linspace(0,250,26),
             color="r", alpha=0.5, label=nano_label);
    # Formatting
    axes2.xaxis.set_minor_locator(AutoMinorLocator())
    plt.xlabel(r"$p_{T}^{trailing}$");
    plt.ylabel("Events");
    plt.legend();
    
def hyp_eta_plot(cms4_df, nano_df, hyp=1,
                 cms4_label="CMS4", nano_label="Nano"):
    # Get synch events
    hyp_synch_events = (np.isin(nano_df.event,
                                cms4_df[cms4_df.hyp_class == hyp].event))
    # Get synch dfs
    cms4_synch_df = cms4_df[cms4_df.hyp_class == hyp]
    nano_synch_df = nano_df[hyp_synch_events]
    
    # Set up figure
    fig = plt.figure(figsize=(6.4*2.25,4.8))

    # Left plot (leaders)
    axes1 = plt.subplot(121)
    plt.hist(cms4_synch_df.leader_eta, bins=np.linspace(-2.5,2.5,11),
             color="b", alpha=0.5, label=cms4_label);
    plt.hist(nano_synch_df[nano_synch_df.is_dilepton_event].leader_eta, bins=np.linspace(-2.5,2.5,11),
             color="r", alpha=0.5, label=nano_label);
    # Formatting
    axes1.xaxis.set_minor_locator(AutoMinorLocator())
    plt.xlabel(r"$\eta^{leading}$");
    plt.ylabel("Events");
    plt.legend();

    # Right plot (laggers)
    axes2 = plt.subplot(122)
    plt.hist(cms4_synch_df.lagger_eta, bins=np.linspace(-2.5,2.5,11),
             color="b", alpha=0.5, label=cms4_label);
    plt.hist(nano_synch_df[nano_synch_df.is_dilepton_event].lagger_eta, bins=np.linspace(-2.5,2.5,11),
             color="r", alpha=0.5, label=nano_label);
    # Formatting
    axes2.xaxis.set_minor_locator(AutoMinorLocator())
    plt.xlabel(r"$\eta^{trailing}$");
    plt.ylabel("Events");
    plt.legend();

# %%
hyp_synch_plot(cms4_synch_df, nano_synch_df)

# %%
# loose-loose
hyp1_synch_events = (np.isin(nano_synch_df.event,
                             cms4_synch_df[cms4_synch_df.hyp_class == 1].event))
# loose&!tight-tight | tight-loose&!tight
hyp2_synch_events = (np.isin(nano_synch_df.event,
                             cms4_synch_df[cms4_synch_df.hyp_class == 2].event))
# tight-tight
hyp3_synch_events = (np.isin(nano_synch_df.event,
                             cms4_synch_df[cms4_synch_df.hyp_class == 3].event))
# opposite sign tight-tight
hyp4_synch_events = (np.isin(nano_synch_df.event,
                             cms4_synch_df[cms4_synch_df.hyp_class == 4].event))
# Z or gamma*
hyp6_synch_events = (np.isin(nano_synch_df.event,
                             cms4_synch_df[cms4_synch_df.hyp_class == 6].event))

# %%
hyp_synch_plot(cms4_synch_df[cms4_synch_df.hyp_class == 1], 
               nano_synch_df[hyp1_synch_events],
               cms4_label=r"CMS4$_{LL}$",
               nano_label=r"Nano(CMS4$_{LL}$)")

# %%
hyp_pt_plot(cms4_synch_df, nano_synch_df, hyp=1,
            cms4_label=r"CMS4$_{LL}$",
            nano_label=r"Nano(CMS4$_{LL}$)")

# %%
hyp_eta_plot(cms4_synch_df, nano_synch_df, hyp=1,
             cms4_label=r"CMS4$_{LL}$",
             nano_label=r"Nano(CMS4$_{LL}$)")

# %%
hyp_synch_plot(cms4_synch_df[cms4_synch_df.hyp_class == 2], 
               nano_synch_df[hyp2_synch_events],
               cms4_label=r"CMS4$_{LT|TL}$",
               nano_label=r"Nano(CMS4$_{LT|TL})$")

# %%
hyp_pt_plot(cms4_synch_df, nano_synch_df, hyp=2,
            cms4_label=r"CMS4$_{LT|TL}$",
            nano_label=r"Nano(CMS4$_{LT|TL}$)")

# %%
hyp_eta_plot(cms4_synch_df, nano_synch_df, hyp=2,
             cms4_label=r"CMS4$_{LT|TL}$",
             nano_label=r"Nano(CMS4$_{LT|TL}$)")

# %%
hyp_synch_plot(cms4_synch_df[cms4_synch_df.hyp_class == 3], 
               nano_synch_df[hyp3_synch_events],
               cms4_label=r"CMS4$_{TT}$",
               nano_label=r"Nano(CMS4$_{TT}$)")

# %%
hyp_pt_plot(cms4_synch_df, nano_synch_df, hyp=3,
            cms4_label=r"CMS4$_{TT}$",
            nano_label=r"Nano(CMS4$_{TT}$)")

# %%
hyp_eta_plot(cms4_synch_df, nano_synch_df, hyp=3,
             cms4_label=r"CMS4$_{TT}$",
             nano_label=r"Nano(CMS4$_{TT}$)")

# %%
hyp_synch_plot(cms4_synch_df[cms4_synch_df.hyp_class == 4], 
               nano_synch_df[hyp4_synch_events],
               cms4_label=r"CMS4$_{(OS)TT}$",
               nano_label=r"Nano(CMS4$_{(OS)TT}$)")

# %%
hyp_pt_plot(cms4_synch_df, nano_synch_df, hyp=4,
            cms4_label=r"CMS4$_{(OS)TT}$",
            nano_label=r"Nano(CMS4$_{(OS)TT}$)")

# %%
hyp_eta_plot(cms4_synch_df, nano_synch_df, hyp=4,
             cms4_label=r"CMS4$_{(OS)TT}$",
             nano_label=r"Nano(CMS4$_{(OS)TT}$)")

# %%
temp_df = nano_synch_df[hyp4_synch_events]

temp_df[temp_df.hyp_class == 2].sort_values("event")
# Out:
#        leader_eta  lagger_isTriggerSafe  leader_isTriggerSafe  lagger_id  \
# entry
# 33118   -0.413391                  True                 False        -11
# 79462    0.075287                  True                  True        -11
# 37584    0.046936                 False                  True         13
# 23850    1.196289                 False                 False         13
# 24630   -1.752441                 False                  True        -13
# 72005    1.317139                 False                  True        -13
# 8847     0.089279                 False                  True        -13
# 8995     0.952393                  True                 False         11
#
#        leader_id  leader_is_loose  lagger_is_loose  leader_is_tight  \
# entry
# 33118        -13             True             True             True
# 79462        -11             True             True             True
# 37584         11             True             True             True
# 23850         13             True             True             True
# 24630        -11             True             True             True
# 72005        -11             True             True             True
# 8847         -11             True             True            False
# 8995          13             True             True             True
#
#        lagger_is_tight  lagger_eta  hyp_class   leader_pt  lagger_pt  \
# entry
# 33118            False   -0.081146          2   56.887234  25.220160
# 79462            False   -0.461487          2  112.809364  17.312859
# 37584            False    0.027081          2   19.011675  12.409923
# 23850            False   -1.782959          2   39.772160  17.956148
# 24630            False   -0.800781          2   35.902866  12.529326
# 72005            False    1.161133          2   45.027367  18.472599
# 8847              True    1.437744          2   42.056767  17.764153
# 8995             False    0.599365          2   62.796078  24.590025
#
#        is_dilepton_event      event
# entry
# 33118               True  134649108
# 79462               True  209208961
# 37584               True  209212074
# 23850               True  213042500
# 24630               True  213044639
# 72005               True  426415456
# 8847                True  458255369
# 8995                True  458255917

# %%
cms4_synch_df[np.isin(cms4_synch_df.event, temp_df[temp_df.hyp_class == 2].event)].sort_values("event")
# Out:
#         leader_eta  lagger_isTriggerSafe  leader_isTriggerSafe  lagger_id  \
# entry
# 172445   -0.413121                 False                 False         13
# 204579    0.074978                 False                  True         13
# 205696   -0.078637                  True                  True         11
# 211410   -1.385651                 False                 False         13
# 212198   -1.752370                  True                  True         11
# 168402    1.316836                 False                  True         13
# 227565    1.649615                 False                  True        -13
# 227740    0.952587                 False                 False        -13
#
#         leader_id  lagger_idx  leader_idx  leader_is_loose  lagger_is_loose  \
# entry
# 172445        -13           1           0             True             True
# 204579        -11           0           0             True             True
# 205696        -11           1           0             True             True
# 211410        -13           1           0             True             True
# 212198        -11           1           0             True             True
# 168402        -11           0           0             True             True
# 227565         11           0           1             True             True
# 227740         13           1           0             True             True
#
#         leader_is_tight  lagger_is_tight  lagger_eta  hyp_class   leader_pt  \
# entry
# 172445             True             True    1.673643          4   56.507320
# 204579             True             True    0.430373          4  112.227379
# 205696             True             True    0.046758          4   57.288387
# 211410             True             True    1.196033          4   47.716400
# 212198             True             True   -0.685585          4   37.753773
# 168402             True             True    0.559215          4   45.126179
# 227565             True             True    1.437326          4   18.741495
# 227740             True             True    0.855184          4   63.172688
#
#          lagger_pt  is_dilepton_event      event  run      lumi
# entry
# 172445   32.095745               True  134649108    1   76483.0
# 204579   36.423603               True  209208961    1  118835.0
# 205696   19.030516               True  209212074    1  118837.0
# 211410   39.699856               True  213042500    1  121013.0
# 212198   32.097923               True  213044639    1  121013.0
# 168402  100.370842               True  426415456    1  242213.0
# 227565   17.741835               True  458255369    1  260299.0
# 185576    1.427926                  True                  True         11
# 185655   -0.124891                  True                  True        -11
# 185759   -1.618998                  True                  True        -11
# 185933    1.439949                 False                  True         13
# 186059    2.055347                 False                  True         13
# 186339    1.168606                 False                  True        -13
# 186423   -1.163423                  True                  True         11
# 187821    1.366800                 False                  True         13
# 188160   -1.810853                 False                 False        -13
# 188261    1.265182                  True                  True         11
# 188427   -0.683043                 False                  True         13
# 188528    1.107322                 False                  True         13
# 188992    1.593077                 False                 False         13
# 189017    1.607779                 False                 False         13
# 189022    0.238519                 False                  True         13
# 186607   -2.317882                 False                  True         13
# 186859    0.592047                 False                  True        -13
# 186918   -0.267099                 False                  True         13
# 187206   -1.937257                 False                 False        -13
# 187256   -2.070801                 False                 False        -13
# ...            ...                   ...                   ...        ...
# 36096     1.464080                 False                  True         13
# 36362    -2.127214                 False                  True         13
# 36583    -1.659306                 False                 False         13
# 36654     1.282125                  True                  True        -11
# 36693     0.237561                 False                  True        -13
# 36689    -0.074962                 False                  True        -13
# 36796     0.059549                 False                  True        -13
# 37710     0.171630                 False                  True        -13
# 38085     0.643314                 False                 False         13
# 38348     0.236914                 False                 False         13
# 38509    -1.910989                 False                 False        -13
# 38923     1.483031                 False                 False        -13
# 38938     1.861053                 False                 False         13
# 39162     0.356645                 False                  True         13
# 39312    -1.587012                 False                  True         13
# 39418    -1.277239                 False                  True         13
# 39485    -0.979298                 False                 False         13
# 39677    -2.070027                 False                  True         13
# 28681    -0.392410                 False                  True        -13
# 28924     0.096517                 False                  True        -13
# 29295    -0.353215                 False                  True        -13
# 29648     0.637901                 False                 False         13
# 29727     0.499752                 False                  True        -13
# 29941     1.179727                 False                 False        -13
# 30122    -0.769755                 False                 False        -13
# 30133    -1.237784                  True                  True        -11
# 30193     1.166766                  True                  True        -11
# 30298     1.585476                  True                  True         11
# 30554     0.184348                 False                  True         13
# 30798    -1.878732                 False                 False        -13
#
#         leader_id  lagger_idx  leader_idx  leader_is_loose  lagger_is_loose  \
# entry
# 182859        -11           0           0             True             True
# 182886        -13           1           0             True             True
# 183031        -11           0           0             True             True
# 183177        -13           1           0             True             True
# 183518         13           1           0             True             True
# 183617         13           1           0             True             True
# 183739        -13           1           0             True             True
# 183751         13           1           0             True             True
# 184032         11           1           0             True             True
# 185410        -11           0           0             True             True
# 185576        -11           1           0             True             True
# 185655         11           1           0             True             True
# 185759         11           1           0             True             True
# 185933        -11           1           0             True             True
# 186059        -11           0           1             True             True
# 186339         11           0           0             True             True
# 186423        -11           1           0             True             True
# 187821        -11           0           0             True             True
# 188160         13           1           0             True             True
# 188261        -11           1           0             True             True
# 188427        -11           0           0             True             True
# 188528        -11           0           0             True             True
# 188992        -13           1           0             True             True
# 189017        -13           1           0             True             True
# 189022        -11           0           0             True             True
# 186607        -11           0           0             True             True
# 186859         11           0           0             True             True
# 186918        -11           0           0             True             True
# 187206         13           1           0             True             True
# 187256         13           1           0             True             True
# ...           ...         ...         ...              ...              ...
# 36096         -11           0           0             True             True
# 36362         -11           0           0             True             True
# 36583         -13           2           0             True             True
# 36654          11           1           0             True             True
# 36693          11           0           0             True             True
# 36689          11           0           0             True             True
# 36796          11           0           0             True             True
# 37710          11           0           0             True             True
# 38085         -13           2           1             True             True
# 38348         -13           2           0             True             True
# 38509          13           1           0             True             True
# 38923          13           1           0             True             True
# 38938         -13           1           0             True             True
# 39162         -11           0           0             True             True
# 39312         -11           0           0             True             True
# 39418         -11           0           0             True             True
# 39485         -13           1           0             True             True
# 39677         -11           0           0             True             True
# 28681          11           0           0             True             True
# 28924          11           0           0             True             True
# 29295          11           0           0             True             True
# 29648         -13           1           0             True             True
# 29727          11           0           1             True             True
# 29941          13           1           0             True             True
# 30122          13           1           0             True             True
# 30133          11           1           0             True             True
# 30193          11           1           0             True             True
# 30298         -11           1           0             True             True
# 30554         -11           0           0             True             True
# 30798          13           1           0             True             True
#
#         leader_is_tight  lagger_is_tight  lagger_eta  hyp_class   leader_pt  \
# entry
# 182859             True             True    1.894740          4  104.380608
# 182886             True             True   -1.834080          4   33.751511
# 183031             True             True   -0.748644          4  218.316559
# 183177             True             True    2.216342          4   63.268448
# 183518             True             True    1.912000          4   80.826355
# 183617             True             True    0.272332          4   41.488556
# 183739             True             True    0.714680          4   42.758339
# 183751             True             True   -2.231261          4   93.279434
# 184032             True             True   -1.751446          4  102.272041
# 185410             True             True   -0.132745          4   72.455894
# 185576             True             True    1.686695          4  157.020645
# 185655             True             True   -0.624199          4   83.903107
# 185759             True             True    1.207687          4   35.622841
# 185933             True             True    2.375568          4   43.493015
# 186059             True             True   -0.025380          4   24.291780
# 186339             True             True    0.355798          4   78.296799
# 186423             True             True   -1.972566          4   97.859184
# 187821             True             True    0.502639          4   29.874884
# 188160             True             True   -0.034874          4  133.607895
# 188261             True             True    0.833140          4   62.587860
# 188427             True             True   -0.072827          4   25.562895
# 188528             True             True    1.661114          4   68.548447
# 188992             True             True    0.067883          4   32.104263
# 189017             True             True   -1.551267          4   51.688347
# 189022             True             True    1.634945          4   21.460112
# 186607             True             True   -0.414101          4   31.798119
# 186859             True             True   -0.789513          4   26.857750
# 186918             True             True    0.023704          4   82.833862
# 187206             True             True   -1.836857          4   89.346008
# 187256             True             True   -0.898717          4   70.281479
# ...                 ...              ...         ...        ...         ...
# 36096              True             True    2.345761          4  123.683044
# 36362              True             True   -0.383423          4   36.979336
# 36583              True             True   -1.913523          4  148.797119
# 36654              True             True    1.377138          4   25.967411
# 36693              True             True   -1.996935          4   72.592354
# 36689              True             True   -0.976387          4   68.520737
# 36796              True             True   -0.761711          4   60.762844
# 37710              True             True   -0.411910          4   30.119328
# 38085              True             True    1.354368          4   24.989613
# 38348              True             True    0.696584          4   26.698324
# 38509              True             True    0.515284          4   63.738995
# 38923              True             True    1.047945          4   82.471825
# 38938              True             True   -0.083001          4   54.163994
# 39162              True             True   -2.336044          4   19.359655
# 39312              True             True    1.481544          4   38.716862
# 39418              True             True   -1.227586          4   64.664154
# 39485              True             True   -1.463648          4   51.625103
# 39677              True             True    0.066460          4   48.319229
# 28681              True             True    1.411965          4   30.675205
# 28924              True             True    0.573201          4   86.784805
# 29295              True             True   -0.155544          4   71.842171
# 29648              True             True    0.755664          4   53.520527
